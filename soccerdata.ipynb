# %%
import sys
import soccerdata as sd

print("Python executable:", sys.executable)
print("soccerdata location:", sd.__file__)
# Out:
# [12/04/25 01:38:52] INFO     No custom team name replacements found. You can configure these in       ]8;id=309249;file:///Users/edwind/opt/anaconda3/lib/python3.9/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=931280;file:///Users/edwind/opt/anaconda3/lib/python3.9/site-packages/soccerdata/_config.py#91\91]8;;\
#                              /Users/edwind/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=307052;file:///Users/edwind/opt/anaconda3/lib/python3.9/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=432576;file:///Users/edwind/opt/anaconda3/lib/python3.9/site-packages/soccerdata/_config.py#197\197]8;;\
#                              /Users/edwind/soccerdata/config/league_dict.json.
# Python executable: /Users/edwind/opt/anaconda3/bin/python
# soccerdata location: /Users/edwind/opt/anaconda3/lib/python3.9/site-packages/soccerdata/__init__.py

# %%
# Create scraper class instance
mh = sd.MatchHistory(leagues="ENG-Premier League", seasons=24)
# Out:
# [12/04/25 01:39:03] INFO     Saving cached data to /Users/edwind/soccerdata/data/MatchHistory        ]8;id=63930;file:///Users/edwind/opt/anaconda3/lib/python3.9/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=438434;file:///Users/edwind/opt/anaconda3/lib/python3.9/site-packages/soccerdata/_common.py#263\263]8;;\

# %%
hist = mh.read_games()
hist.head()
# Out:
# [12/04/25 01:39:54] INFO     Parsing league=E0 season=2425                                      ]8;id=343635;file:///Users/edwind/opt/anaconda3/lib/python3.9/site-packages/soccerdata/match_history.py\match_history.py]8;;\:]8;id=393468;file:///Users/edwind/opt/anaconda3/lib/python3.9/site-packages/soccerdata/match_history.py#17\17]8;;\
#                                                                           date  \
# league             season game
# ENG-Premier League 2425   2024-08-16 Man United-Fulham     2024-08-16 20:00:00
#                           2024-08-17 Arsenal-Wolves        2024-08-17 15:00:00
#                           2024-08-17 Everton-Brighton      2024-08-17 15:00:00
#                           2024-08-17 Ipswich-Liverpool     2024-08-17 12:30:00
#                           2024-08-17 Newcastle-Southampton 2024-08-17 15:00:00
#
#                                                              home_team  \
# league             season game
# ...

# %%
hist.columns[22:49]
# Out:
# Index(['B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'BFH', 'BFD', 'BFA',
#        'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', '1XBH', '1XBD', '1XBA',
#        'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'BFEH', 'BFED', 'BFEA'],
#       dtype='object')

# %%
hist.iloc[:, 22:49].head()
# Out:
#                                                             B365H  B365D  \
# league             season game
# ENG-Premier League 2425   2024-08-16 Man United-Fulham       1.60   4.20
#                           2024-08-17 Arsenal-Wolves          1.18   7.50
#                           2024-08-17 Everton-Brighton        2.63   3.30
#                           2024-08-17 Ipswich-Liverpool       8.50   5.50
#                           2024-08-17 Newcastle-Southampton   1.36   5.25
#
#                                                             B365A   BWH  BWD  \
# league             season game
# ENG-Premier League 2425   2024-08-16 Man United-Fulham       5.25  1.60  4.4
#                           2024-08-17 Arsenal-Wolves         13.00  1.20  7.5
#                           2024-08-17 Everton-Brighton        2.63  2.65  3.4
#                           2024-08-17 Ipswich-Liverpool       1.33  7.50  5.5
#                           2024-08-17 Newcastle-Southampton   8.00  1.35  5.5
#
# ...

# %%
hist[['AvgH', 'AvgD', 'AvgA']]
# Out:
#                                                             AvgH  AvgD   AvgA
# league             season game
# ENG-Premier League 2425   2024-08-16 Man United-Fulham      1.62  4.36   5.15
#                           2024-08-17 Arsenal-Wolves         1.18  7.86  15.87
#                           2024-08-17 Everton-Brighton       2.67  3.41   2.68
#                           2024-08-17 Ipswich-Liverpool      8.28  5.76   1.34
#                           2024-08-17 Newcastle-Southampton  1.35  5.62   8.10
# ...                                                          ...   ...    ...
#                           2025-05-25 Newcastle-Everton      1.32  5.60   8.77
#                           2025-05-25 Nott'm Forest-Chelsea  3.09  3.72   2.20
#                           2025-05-25 Southampton-Arsenal    9.45  5.83   1.29
#                           2025-05-25 Tottenham-Brighton     4.23  4.43   1.71
#                           2025-05-25 Wolves-Brentford       2.71  3.76   2.43
#
# ...

# %%
hist.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
#        'HTR', 'referee',
#        ...
#        'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA',
#        'AvgCAHH', 'AvgCAHA', 'BFECAHH', 'BFECAHA'],
#       dtype='object', length=118)

# %%
hist[['home_team', 'away_team','FTR']]
# Out:
#                                                                 home_team  \
# league             season game
# ENG-Premier League 2425   2024-08-16 Man United-Fulham         Man United
#                           2024-08-17 Arsenal-Wolves               Arsenal
#                           2024-08-17 Everton-Brighton             Everton
#                           2024-08-17 Ipswich-Liverpool            Ipswich
#                           2024-08-17 Newcastle-Southampton      Newcastle
# ...                                                                   ...
#                           2025-05-25 Newcastle-Everton          Newcastle
#                           2025-05-25 Nott'm Forest-Chelsea  Nott'm Forest
#                           2025-05-25 Southampton-Arsenal      Southampton
#                           2025-05-25 Tottenham-Brighton         Tottenham
#                           2025-05-25 Wolves-Brentford              Wolves
#
# ...

# %%
hist[hist['home_team'] == 'Man United'][['home_team','away_team','FTR']]
# Out:
#                                                                  home_team  \
# league             season game
# ENG-Premier League 2425   2024-08-16 Man United-Fulham          Man United
#                           2024-09-01 Man United-Liverpool       Man United
#                           2024-09-29 Man United-Tottenham       Man United
#                           2024-10-19 Man United-Brentford       Man United
#                           2024-11-03 Man United-Chelsea         Man United
#                           2024-11-10 Man United-Leicester       Man United
#                           2024-12-01 Man United-Everton         Man United
#                           2024-12-07 Man United-Nott'm Forest   Man United
#                           2024-12-22 Man United-Bournemouth     Man United
#                           2024-12-30 Man United-Newcastle       Man United
#                           2025-01-16 Man United-Southampton     Man United
# ...
